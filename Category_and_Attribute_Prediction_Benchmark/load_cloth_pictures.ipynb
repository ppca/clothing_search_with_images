# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import helper
image_folder_path = 'Img/img/'
# Out:
# Using TensorFlow backend.

# %%
label_txt = 'list_category_img.txt'

# %%
cloth_files, cloth_targets = helper.load_dataset(image_folder_path, label_txt)

# %%
train_files, train_targets, val_files, val_targets, test_files, test_targets = helper.train_val_test_split(cloth_files, cloth_targets, 0.8)

# %%
len(train_files)
# Out:
# 11536

# %%
len(val_files)
# Out:
# 46289

# %%
train_tensors = helper.paths_to_tensor(train_files)
val_tensors = helper.paths_to_tensor(val_files)
test_tensors = helper.paths_to_tensor(test_files)
# Out:
# 100%|██████████| 11478/11478 [00:42<00:00, 272.30it/s]
#  89%|████████▉ | 40999/45852 [02:48<00:23, 209.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jzheng/Desktop/anaconda/envs/aind-dog/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2880                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2881                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2882             finally:
#
# <ipython-input-4-b31f815538e7> in <module>()
#       1 train_tensors = helper.paths_to_tensor(train_files)
# ----> 2 val_tensors = helper.paths_to_tensor(val_files)
#       3 test_tensors = helper.paths_to_tensor(test_files)
#
# /Users/jzheng/myPlayground/clothing_project/Category_and_Attribute_Prediction_Benchmark/helper.py in paths_to_tensor(img_paths)
#      41 def paths_to_tensor(img_paths: list):
# ---> 42     list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
#      43     return np.vstack(list_of_tensors)
#
# /Users/jzheng/myPlayground/clothing_project/Category_and_Attribute_Prediction_Benchmark/helper.py in <listcomp>(.0)
#      41 def paths_to_tensor(img_paths: list):
# ---> 42     list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
#      43     return np.vstack(list_of_tensors)
#
# /Users/jzheng/myPlayground/clothing_project/Category_and_Attribute_Prediction_Benchmark/helper.py in path_to_tensor(img_path)
#      36     # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
# ---> 37     x = image.img_to_array(img)
#      38     # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
#
# /Users/jzheng/Desktop/anaconda/envs/aind-dog/lib/python3.5/site-packages/keras/preprocessing/image.py in img_to_array(img, data_format)
#     287     # but original PIL image has format (width, height, channel)
# --> 288     x = np.asarray(img, dtype=K.floatx())
#     289     if len(x.shape) == 3:
#
# /Users/jzheng/Desktop/anaconda/envs/aind-dog/lib/python3.5/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
np.mean(np.random.sample(250000)>0.8)
# Out:
# 0.19974
